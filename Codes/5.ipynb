# %% [markdown]
# #**5: Train 2 NLP Models<br>**
# 1. From Blank NLP model
# 2. From Existing NLP model "en_core_web_sm"
# * Split the training corpus into train and test sets.
# * Train the two models with the training set
# * Test the two models with the test set
#     * Also test the default untrained NLP Model
# * Compare the performances
# <hr>

# %% [markdown]
# # Getting the Training Corpus

# %% [markdown]
# 'drive.mount('/content/drive/')' mounts Google Drive to Google Colab notebook.

# %%
#Mounting Google Drive

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# The code below reads a CSV file containing training data for an NLP model, converts the data into a list, and converts the string representation of the annotation dictionaries into actual dictionary objects. This is a common preprocessing step when working with NLP models that require annotated data for training.

# %%
#Getting the training corpus as tc
import pandas as pd
tc= pd.read_csv('/content/drive/MyDrive/Final (Completed)/training_corpus.csv')

#Converting the dataframe into list
all_train_data= list(tc.values)
print(type(all_train_data[0][1]))

#Converting the annotations into dictionary
import ast
for i in range(0,len(all_train_data)):
    all_train_data[i][1]=ast.literal_eval(str(all_train_data[i][1]))
print(type(all_train_data[0][1]))
# Out:
# <class 'str'>
# <class 'dict'>

# %% [markdown]
# The code below is a common preprocessing step when working with NLP models that require a fixed set of labels for classification or annotation. The list of labels can be used to define the output layer of the NLP model and to ensure that the model produces outputs that are consistent with the available labels.

# %%
#Getting the labels
labels= pd.read_csv('/content/drive/MyDrive/Final (Completed)/labels.csv')
print([l for l in labels['0']],':',len(labels))
# Out:
# ['DOCUMENT', 'PROCESS', 'PERSON', 'PORTAL', 'MOBILE_APP', 'CSC', 'PERMISSION', 'ORG'] : 8

# %% [markdown]
# The code below splits the original training data into two subsets: train_data and test_data. This is a common preprocessing step when training a machine learning model. The training data subset is used to train the model, and the test data subset is used to evaluate the model's performance on unseen data. The train_test_split function ensures that the data is split randomly and in a way that preserves the distribution of labels in the original data. the random_state value is the seed value for random slpit.

# %%
#Splitting the Training Corpus into Train and Test Sets
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(all_train_data, test_size=0.2, random_state=42)
print("Train Data:",len(train_data),"\nTest Data:",len(test_data))
# Out:
# Train Data: 1032
# Test Data: 258

# %% [markdown]
# #Getting the two NLP Models to train

# %%
import spacy
# A Blank Model
nlp1= spacy.blank('en')
nlp1.add_pipe('ner')
nlp1.begin_training()

# An Existing NER Model
nlp2= spacy.load('en_core_web_sm')

# Getting pipeline component
ner1= nlp1.get_pipe("ner") 
ner2= nlp2.get_pipe("ner") 

# Adding labels to the 'ner1' and 'ner2'
for label in labels:
    ner1.add_label(label)
    ner2.add_label(label)

#Disable pipeline components that doesn't need to change in nlp2
pipe_exceptions=["ner","trf_wordpiecer","trf_tok2vec"]
unaffected_pipes=[pipe for pipe in nlp2.pipe_names if pipe not in pipe_exceptions]
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %% [markdown]
# First, we have created a blank model for the English language by calling the spacy.blank() function and passing the 'en' parameter. We have stored this model in a variable called nlp1.
#
# Next, we have added a named entity recognition (NER) pipeline component to the nlp1 model by calling the nlp1.add_pipe('ner') function. We have then started the training process for the model by calling the nlp1.begin_training() function.
#
# We have also loaded an existing NER model called 'en_core_web_sm' into the nlp2 variable by calling the spacy.load() function and passing the 'en_core_web_sm' parameter.
#
# To get the NER pipeline component of both models, we have called the nlp1.get_pipe("ner") and nlp2.get_pipe("ner") functions respectively and stored their results in the ner1 and ner2 variables.
#
# We have then added labels to both ner1 and ner2 by iterating through a list of labels and calling the ner1.add_label(label) and ner2.add_label(label) functions.
#
# Finally, we have disabled some of the pipeline components in the nlp2 model that we do not need to change. Specifically, we have created a list called pipe_exceptions containing the names of the pipeline components we want to keep ("ner", "trf_wordpiecer", and "trf_tok2vec"), and then we have created another list called unaffected_pipes containing the names of all the pipeline components in nlp2 except for those listed in pipe_exceptions. We can use this list to selectively enable or disable pipeline components as needed.

# %% [markdown]
# The purpose of this code is to set up two English NLP models, one blank and one pre-trained, and prepare them for training on a Named Entity Recognition task. The blank model is trained from scratch, while the pre-trained model is fine-tuned to improve its performance on the specific task. The labels list is added to both models to ensure that they are consistent. Finally, the pipe_exceptions and unaffected_pipes lists are used to manage the pipeline components that need to be modified and those that do not in `nlp2` model.

# %%
# Train the NER component
import random
from spacy.util import minibatch, compounding
from spacy.training.example import Example
n_iter = 10
other_pipes = [pipe for pipe in nlp2.pipe_names if pipe != 'ner']
with nlp2.disable_pipes(*other_pipes):
    optimizer1 = nlp1.create_optimizer()
    optimizer2 = nlp2.create_optimizer()
    for i in range(n_iter):
        random.shuffle(train_data)
        losses1 = {}
        losses2 = {}
        batches = minibatch(train_data, size=compounding(4.0, 32.0, 1.001))
        for batch in batches:
            texts, annotations = zip(*batch)
            for j in range(0,len(texts)):
                doc1 = nlp1.make_doc(texts[j])
                doc2 = nlp2.make_doc(texts[j])
                example1 = Example.from_dict(doc1, annotations[j])
                example2 = Example.from_dict(doc2, annotations[j])
                nlp1.update([example1], sgd=optimizer1, drop=0.35, losses=losses1)
                nlp2.update([example2], sgd=optimizer2, drop=0.35, losses=losses2)
        print(f'nlp1_Epoch {i}: {losses1}')
        print(f'nlp2_Epoch {i}: {losses2}')
# Save the trained model to disk
nlp1.to_disk('/content/drive/MyDrive/Final (Completed)/nlp_model_1')
nlp2.to_disk('/content/drive/MyDrive/Final (Completed)/nlp_model_2')
# Out:
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY is being implemented through PMAMs Pradh..." with entities "[(4, 9, 'ORG'), (39, 43, 'PERSON')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY offers comprehensive medical coverage to cit..." with entities "[(0, 5, 'ORG'), (82, 101, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY is a great initiative by the government to p..." with entities "[(0, 5, 'ORG'), (62, 74, 'PROCESS'), (79, 88, 'PRO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY Beneficiary was grateful to the Empanell..." with entities "[(4, 21, 'PERSON'), (42, 61, 'ORG'), (72, 77, 'ORG...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY offers a hassle-free way for the registered ..." with entities "[(0, 5, 'ORG'), (50, 67, 'PERSON'), (78, 89, 'PROC...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Once the PMJAY Beneficiary is verified to be a Gol..." with entities "[(9, 26, 'PERSON'), (47, 60, 'DOCUMENT'), (88, 107...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Inform that the Empanelled Hospitalization service..." with entities "[(16, 35, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY is the world’s largest health Insurance Comp..." with entities "[(0, 5, 'ORG'), (36, 53, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY has made healthcare more accessible for peop..." with entities "[(0, 5, 'ORG'), (81, 100, 'ORG'), (129, 143, 'PERS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The scheme will cover a range of medical services ..." with entities "[(60, 79, 'ORG'), (88, 99, 'PROCESS')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients and healthcare providers have given posit..." with entities "[(0, 7, 'PERSON'), (54, 62, 'DOCUMENT'), (77, 80, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Medical examination , Treatment and Consultation P..." with entities "[(22, 31, 'PROCESS'), (36, 48, 'PROCESS'), (55, 74...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients can utilize the Am I Eligible Website to ..." with entities "[(0, 7, 'PERSON'), (25, 46, 'PORTAL'), (110, 115, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides a health cover of up to Rs 5 lakh p..." with entities "[(0, 5, 'ORG'), (101, 120, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Through the PMJAY scheme, PMJAY Beneficiary can av..." with entities "[(12, 17, 'ORG'), (26, 43, 'PERSON'), (79, 90, 'PR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Costs relating to pre and post Empanelled Hospital..." with entities "[(31, 50, 'ORG'), (60, 71, 'PROCESS'), (144, 149, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients can easily check their eligibility for th..." with entities "[(0, 7, 'PERSON'), (52, 57, 'ORG'), (74, 95, 'PORT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY is the biggest health Insurance Companyschem..." with entities "[(0, 5, 'ORG'), (28, 45, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Patient is provided with free Treatment and Em..." with entities "[(4, 11, 'PERSON'), (34, 43, 'PROCESS'), (48, 67, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The App can be downloaded at https://play.google.c..." with entities "[(79, 82, 'ORG'), (83, 88, 'ORG'), (89, 95, 'DOCUM...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY scheme is a boon for people who need Emp..." with entities "[(4, 9, 'ORG'), (47, 66, 'ORG'), (123, 132, 'PROCE...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients can now easily register for medical servi..." with entities "[(0, 7, 'PERSON'), (66, 77, 'CSC'), (104, 109, 'OR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ESIS, the Employees' State Insurance CompanyScheme..." with entities "[(27, 44, 'ORG'), (57, 74, 'PERSON'), (118, 123, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAYhas been a lifesaver for Ms." with entities "[(0, 5, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Medical Package provided under PMJAY cover the..." with entities "[(4, 19, 'DOCUMENT'), (35, 40, 'ORG'), (71, 90, 'O...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Insurance Company have also Medical Reported t..." with entities "[(4, 21, 'ORG'), (32, 46, 'DOCUMENT'), (94, 99, 'O...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "And subject to approval , you will receive the-car..." with entities "[(45, 51, 'DOCUMENT')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The aggrieved party can submit grievances through ..." with entities "[(78, 83, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Empanelled Hospital under the PMJAYtrust was a..." with entities "[(4, 23, 'ORG'), (34, 39, 'ORG'), (69, 86, 'PERSON...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "A user friendly web portal “ https://mera.PMJAY.go..." with entities "[(42, 47, 'ORG'), (130, 135, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients seeking medical Treatment from an Empanel..." with entities "[(0, 7, 'PERSON'), (25, 34, 'PROCESS'), (43, 62, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Electronic Health Care Profiles EHCPs created ..." with entities "[(36, 40, 'ORG'), (56, 61, 'ORG'), (95, 102, 'PERS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The online services provided through the EHCPortal..." with entities "[(41, 45, 'ORG'), (134, 139, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Feedback from users of the EHCPortal has been ..." with entities "[(4, 12, 'DOCUMENT'), (31, 35, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text ",RBSK PMJAY, also known as ‘PMJAY’, is a flagship ..." with entities "[(6, 11, 'ORG'), (28, 33, 'ORG'), (57, 74, 'ORG'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY Kiosk are manned by PMAMs who are traine..." with entities "[(4, 15, 'CSC'), (30, 34, 'PERSON'), (80, 85, 'ORG...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY helps citizens to get access to quality heal..." with entities "[(0, 5, 'ORG'), (84, 103, 'ORG'), (153, 157, 'ORG'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides financial assistance to citizens fo..." with entities "[(0, 5, 'ORG'), (76, 95, 'ORG'), (144, 148, 'ORG')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY Beneficiary was delighted to know that h..." with entities "[(4, 21, 'PERSON'), (59, 78, 'ORG'), (103, 108, 'O...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Medical Package provided by PMJAY include Diag..." with entities "[(4, 19, 'DOCUMENT'), (32, 37, 'ORG'), (46, 57, 'P...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Most people taking advantage of PMJAY are highly s..." with entities "[(32, 37, 'ORG'), (99, 103, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The EHCPs offered under PMJAY include provision fo..." with entities "[(4, 8, 'ORG'), (24, 29, 'ORG'), (67, 86, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY scheme has been a great help to the peop..." with entities "[(4, 9, 'ORG'), (81, 100, 'ORG'), (112, 121, 'PROC...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY Beneficiary are entitled to cashless and pap..." with entities "[(0, 17, 'PERSON'), (81, 100, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "General Doctor are at the forefront of the PMJAY s..." with entities "[(0, 14, 'PERSON'), (43, 48, 'ORG'), (74, 93, 'ORG...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The ISA of PMJAY has enabled the efficient integra..." with entities "[(4, 7, 'ORG'), (11, 16, 'ORG'), (77, 94, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Under PMJAY, PMJAY Beneficiary will receive a gold..." with entities "[(6, 11, 'ORG'), (13, 30, 'PERSON'), (60, 77, 'ORG...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides health Insurance Companyto the vuln..." with entities "[(0, 5, 'ORG'), (22, 39, 'ORG'), (116, 133, 'ORG')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY has made it easier for people to Claim healt..." with entities "[(0, 5, 'ORG'), (39, 44, 'DOCUMENT'), (52, 69, 'OR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "As per the Government Claim, PMJAY provides Insura..." with entities "[(22, 27, 'DOCUMENT'), (29, 34, 'ORG'), (44, 61, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY scheme has helped many people who cannot..." with entities "[(4, 9, 'ORG'), (68, 87, 'ORG'), (123, 132, 'PROCE...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "If the pre - authorization is not approved , the s..." with entities "[(84, 101, 'PERSON'), (162, 171, 'PROCESS'), (184,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "People can avail the benefits of PMJAY by getting ..." with entities "[(33, 38, 'ORG'), (55, 74, 'ORG'), (86, 95, 'PROCE...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides a comprehensive health Insurance Co..." with entities "[(0, 5, 'ORG'), (38, 55, 'ORG'), (70, 88, 'PERSON'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Empanelled Hospitalization is an important compone..." with entities "[(0, 19, 'ORG'), (56, 61, 'ORG'), (66, 84, 'PERSON...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Healthcare providers have Medical Reported that th..." with entities "[(26, 40, 'DOCUMENT'), (52, 55, 'ORG'), (59, 64, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The EHCPs offered under PMJAY provide financial as..." with entities "[(4, 8, 'ORG'), (24, 29, 'ORG'), (92, 101, 'PROCES...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text ",EMR PMJAY or PMJAY is the flagship Health Insuran..." with entities "[(5, 10, 'ORG'), (14, 19, 'ORG'), (43, 60, 'ORG'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY is being implemented by PMAMs Pradhan Ma..." with entities "[(4, 9, 'ORG'), (34, 38, 'PERSON')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "All MEDCOs under the PMJAY scheme are equipped wit..." with entities "[(4, 9, 'PERSON'), (21, 26, 'ORG'), (52, 70, 'PERS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY Kiosk are equipped with the necessary to..." with entities "[(4, 15, 'CSC'), (76, 80, 'PERSON'), (144, 149, 'O...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides an integrated platform for the regi..." with entities "[(0, 5, 'ORG'), (57, 74, 'PERSON'), (85, 96, 'PROC...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY seeks to ensure that entitled poor and vulne..." with entities "[(0, 5, 'ORG'), (142, 161, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Empanelled Hospital made the PMJAY Beneficiary..." with entities "[(4, 23, 'ORG'), (33, 50, 'PERSON'), (107, 112, 'O...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients have Medical Reported that the ISA of PMJ..." with entities "[(0, 7, 'PERSON'), (14, 28, 'DOCUMENT'), (40, 43, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The EHCPortal has made it easier for people to acc..." with entities "[(4, 8, 'ORG'), (70, 75, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY, also known as PMJAY and PMAM initiative, is..." with entities "[(0, 5, 'ORG'), (21, 26, 'ORG'), (31, 35, 'PERSON'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY is one of the most important components of P..." with entities "[(0, 5, 'ORG'), (64, 69, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "People can Claim reimbursements for the Empanelled..." with entities "[(11, 16, 'DOCUMENT'), (40, 59, 'ORG'), (91, 96, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides access to free healthcare services ..." with entities "[(0, 5, 'ORG'), (100, 117, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY scheme has been designed to protect citi..." with entities "[(4, 9, 'ORG'), (94, 113, 'ORG'), (155, 159, 'PERS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides Electronic Health Care Plans EHCPs ..." with entities "[(0, 5, 'ORG'), (44, 48, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Insurance Company associated with PMJAY have a..." with entities "[(4, 21, 'ORG'), (38, 43, 'ORG'), (54, 68, 'DOCUME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "You are not required to pay any money for your Emp..." with entities "[(47, 66, 'ORG'), (106, 125, 'ORG'), (136, 145, 'P...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMAMIT portal is the official EHCP Registratio..." with entities "[(4, 8, 'PERSON'), (34, 56, 'CSC'), (61, 66, 'ORG'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Grievances can be registered through an online gri..." with entities "[(91, 96, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients can get free Consultation with a General ..." with entities "[(0, 7, 'PERSON'), (22, 34, 'PROCESS'), (42, 56, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY aims to reduce the financial burden on Patie..." with entities "[(0, 5, 'ORG'), (45, 52, 'PERSON'), (84, 95, 'PROC...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides Insurance Companycoverage to those ..." with entities "[(0, 5, 'ORG'), (15, 32, 'ORG'), (100, 117, 'ORG')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMAMs Pradhan Mantri Arogya Mitras are responsible..." with entities "[(0, 4, 'PERSON'), (81, 86, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ISA is an Insurance CompanyService Agency model wh..." with entities "[(0, 3, 'ORG'), (10, 27, 'ORG'), (116, 133, 'PERSO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Subsequent pre - authorizations will be required a..." with entities "[(66, 83, 'PERSON'), (100, 119, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients who wish to find out whether they are eli..." with entities "[(0, 7, 'PERSON'), (64, 69, 'ORG'), (91, 112, 'POR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Under the PMJAY scheme, MEDCOs Medical Colleges an..." with entities "[(10, 15, 'ORG'), (24, 29, 'PERSON'), (52, 71, 'OR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients can use the Am I Eligible App to determin..." with entities "[(0, 7, 'PERSON'), (21, 38, 'MOBILE_APP'), (77, 82...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients can use the Am I Eligible App to check if..." with entities "[(0, 7, 'PERSON'), (21, 38, 'MOBILE_APP'), (77, 82...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Through the PMAMIT portal, users can access the EH..." with entities "[(12, 16, 'PERSON'), (48, 70, 'CSC'), (75, 80, 'OR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMAMIT portal provides comprehensive informati..." with entities "[(4, 8, 'PERSON'), (60, 82, 'CSC'), (87, 92, 'ORG'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Details are available at https://www.PMJAY.gov.in/..." with entities "[(37, 42, 'ORG'), (135, 152, 'PERSON'), (248, 265,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Electronic Health Care Profiles EHCPs created ..." with entities "[(36, 40, 'ORG'), (56, 61, 'ORG'), (85, 102, 'PERS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Key Features and Benefits of PMJAY provides free E..." with entities "[(29, 34, 'ORG'), (49, 68, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Drop in number of cases Medical Reporting dissatis..." with entities "[(24, 38, 'DOCUMENT'), (63, 68, 'ORG'), (93, 107, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMAM informs the PMJAY Beneficiary that they a..." with entities "[(4, 8, 'PERSON'), (21, 38, 'PERSON'), (71, 80, 'P...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Thousands of people have already benefitted from t..." with entities "[(53, 58, 'ORG'), (92, 111, 'ORG'), (127, 141, 'PE...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY is implemented in partnership with Insurance..." with entities "[(0, 5, 'ORG'), (41, 58, 'ORG'), (103, 120, 'ORG')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The scheme provides comprehensive coverage for sec..." with entities "[(75, 94, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients in need of medical Treatment are encourag..." with entities "[(0, 7, 'PERSON'), (28, 37, 'PROCESS'), (68, 87, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "If the Treatment Medical Package requires Pre - au..." with entities "[(7, 16, 'PROCESS'), (17, 32, 'DOCUMENT'), (68, 72...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Empanelled Hospital under PMJAY offer Medical Pack..." with entities "[(0, 19, 'ORG'), (26, 31, 'ORG'), (38, 53, 'DOCUME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides access to Empanelled Hospitalizatio..." with entities "[(0, 5, 'ORG'), (25, 44, 'ORG'), (85, 103, 'PERSON...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAYhas enabled Ms." with entities "[(0, 5, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY allows the Treating Doctor to provide Treatm..." with entities "[(0, 5, 'ORG'), (17, 32, 'PERSON'), (44, 63, 'DOCU...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides health Insurance Companyto the PMJA..." with entities "[(0, 5, 'ORG'), (22, 39, 'ORG'), (46, 63, 'PERSON'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY Beneficiary Verification Empanelled Hospital..." with entities "[(0, 17, 'PERSON'), (31, 50, 'ORG'), (72, 97, 'PER...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "lakhs per family, which can be used to pay for Emp..." with entities "[(47, 66, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients should use the Am I Eligible App to find ..." with entities "[(0, 7, 'PERSON'), (24, 41, 'MOBILE_APP'), (79, 84...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides Electronic Health Care Plans EHCPs ..." with entities "[(0, 5, 'ORG'), (44, 48, 'ORG'), (100, 119, 'ORG')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MEDCOs listed under the PMJAY scheme are the regis..." with entities "[(0, 5, 'PERSON'), (24, 29, 'ORG'), (56, 75, 'ORG'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Electronic Health Care Plans EHCPs offered und..." with entities "[(33, 37, 'ORG'), (53, 58, 'ORG'), (139, 158, 'ORG...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "In addition , Rashtriya Swasthya Bima Yojana RSBY ..." with entities "[(55, 61, 'DOCUMENT'), (85, 90, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "lakhs per family per year for secondary and tertia..." with entities "[(58, 77, 'ORG'), (143, 147, 'PERSON'), (149, 152,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Admission Raising Pre-Authorization Request PMJAY ..." with entities "[(18, 43, 'PERMISSION'), (44, 49, 'ORG'), (57, 76,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "s,Government PMJAY or PMJAY is an ambitious health..." with entities "[(13, 18, 'ORG'), (22, 27, 'ORG'), (51, 68, 'ORG')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Service Parameters Please Ö tick appropriate box R..." with entities "[(63, 80, 'PERSON'), (92, 101, 'PROCESS'), (122, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Treatment Medical Report, MEDCO, outlines the ..." with entities "[(4, 13, 'PROCESS'), (14, 28, 'DOCUMENT'), (30, 35...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text ",Poor PMJAY, also known as the PMJAY, is a flagshi..." with entities "[(6, 11, 'ORG'), (31, 36, 'ORG'), (97, 101, 'PERSO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Insurance Company can offer a variety of health In..." with entities "[(0, 17, 'ORG'), (48, 65, 'ORG'), (77, 82, 'ORG'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY helps to make Diagnostics services more acce..." with entities "[(0, 5, 'ORG'), (20, 31, 'PROCESS'), (91, 108, 'PE...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Insurance Company have appreciated the initiat..." with entities "[(4, 21, 'ORG'), (63, 68, 'ORG'), (80, 97, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Additionally , the PMJAY Beneficiary is informed o..." with entities "[(19, 36, 'PERSON'), (117, 136, 'ORG'), (143, 154,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The EHCPortal has made it much easier for people t..." with entities "[(4, 8, 'ORG'), (107, 112, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The SHA should inform the PMJAY Beneficiary , that..." with entities "[(4, 7, 'ORG'), (26, 43, 'PERSON'), (136, 155, 'OR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ortal The Feedback from the PMJAY Beneficiary of P..." with entities "[(10, 18, 'DOCUMENT'), (28, 45, 'PERSON'), (49, 54...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Insurance Company have Medical Reported that t..." with entities "[(4, 21, 'ORG'), (27, 41, 'DOCUMENT'), (86, 91, 'O...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients eligible for PMJAY are required to submit..." with entities "[(0, 7, 'PERSON'), (22, 27, 'ORG'), (53, 78, 'PERM...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MEDCOs registered under the PMJAY scheme are equip..." with entities "[(0, 5, 'PERSON'), (28, 33, 'ORG'), (59, 77, 'PERS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients who wish to avail the benefits of PMJAY a..." with entities "[(0, 7, 'PERSON'), (43, 48, 'ORG'), (55, 74, 'ORG'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The guidebook also provides examples of standard m..." with entities "[(80, 83, 'ORG'), (88, 91, 'ORG'), (123, 140, 'PER...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "All MEDCOs listed under the PMJAY scheme are equip..." with entities "[(4, 9, 'PERSON'), (28, 33, 'ORG'), (59, 77, 'PERS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Picture of PMJAY captures the essence of the f..." with entities "[(4, 11, 'DOCUMENT'), (15, 20, 'ORG'), (65, 82, 'O...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY is an ambitious government scheme which inte..." with entities "[(0, 5, 'ORG'), (153, 172, 'ORG'), (255, 272, 'PER...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "lakh per family per year for secondary and tertiar..." with entities "[(57, 76, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY allows people to make a Claim for medical Tr..." with entities "[(0, 5, 'ORG'), (30, 35, 'DOCUMENT'), (48, 57, 'PR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MEDCOs under the PMJAY scheme are stocked with Gen..." with entities "[(0, 5, 'PERSON'), (17, 22, 'ORG'), (47, 65, 'PERS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "With the help of PMJAY, registered PMJAY Beneficia..." with entities "[(17, 22, 'ORG'), (35, 52, 'PERSON'), (71, 82, 'PR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY, also known as PMJAY PMAM , is a flagship he..." with entities "[(0, 5, 'ORG'), (21, 26, 'ORG'), (27, 31, 'PERSON'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Feedback from users of the EHCPortal has been ..." with entities "[(4, 12, 'DOCUMENT'), (31, 35, 'ORG'), (135, 140, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Empanelled Hospital will not collect any money..." with entities "[(4, 23, 'ORG'), (60, 77, 'PERSON'), (135, 146, 'P...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY has set up Call-Centre to provide round-the-..." with entities "[(0, 5, 'ORG'), (17, 28, 'ORG'), (100, 117, 'ORG')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# nlp1_Epoch 0: {'ner': 1806.2281800729045}
# nlp2_Epoch 0: {'ner': 1184.56735712692}
# nlp1_Epoch 1: {'ner': 564.6411237148457}
# nlp2_Epoch 1: {'ner': 202.92248622796677}
# nlp1_Epoch 2: {'ner': 584.2392605513691}
# nlp2_Epoch 2: {'ner': 282.7223886777114}
# nlp1_Epoch 3: {'ner': 314.5579534688138}
# nlp2_Epoch 3: {'ner': 104.00410918707257}
# nlp1_Epoch 4: {'ner': 299.6152072470789}
# nlp2_Epoch 4: {'ner': 182.89037431958937}
# nlp1_Epoch 5: {'ner': 298.85909949279613}
# nlp2_Epoch 5: {'ner': 107.56560717462732}
# nlp1_Epoch 6: {'ner': 312.6654001138403}
# nlp2_Epoch 6: {'ner': 104.67959599115633}
# nlp1_Epoch 7: {'ner': 372.6034761933004}
# nlp2_Epoch 7: {'ner': 95.4047239584839}
# nlp1_Epoch 8: {'ner': 299.4500198138731}
# nlp2_Epoch 8: {'ner': 123.33520294560097}
# nlp1_Epoch 9: {'ner': 163.24802787621647}
# nlp2_Epoch 9: {'ner': 36.878218374097415}

# %% [markdown]
# This code trains two named entity recognition (NER) models, nlp1 and nlp2, using a list of training data called train_data. The training process consists of iterating over the training data n_iter times, shuffling the data at the beginning of each epoch. For each epoch, the training data is divided into batches using the minibatch function, which takes a sequence of examples and returns a sequence of batches, where each batch contains a variable number of examples. The size of each batch is increased exponentially with each iteration of the loop, starting at 4 and capped at 32. (e.g., (1,32,2) -> batch size would be:- 1,2,4,8,16,32.)
#
# During each iteration of the inner loop over the batches, the code extracts the text and the annotations from each example in the batch using the zip function. For each text in the batch, two Spacy Doc objects are created, one for each NER model, using the make_doc function. Then, two Example objects are created from each Doc and its corresponding annotations using the Example.from_dict method. Finally, the update method of each NER model is called with its corresponding Example object, the sgd optimizer, a dropout rate of 0.35, and an empty dictionary for storing the loss values.
#
# At the end of each epoch, the loss values for each NER model are printed. After all epochs are completed, the trained models are saved to disk using the to_disk method.
#
# It's worth noting that nlp1 and nlp2 are assumed to have been initialized and configured with their respective components before this code snippet. Also, nlp1 and nlp2 may refer to the same instance of the spacy.Language class, but with different configurations for their NER components.
#
# # Code Break Down
# **`nlp1.update([example1], sgd=optimizer, drop=0.35, losses=losses1)`**<br>
# **`nlp1`**: This is the NLP model instance that we want to update.<br>
# **`example1`**: This is a new example that we want to use to update the model. The example is typically a text string and any relevant metadata, such as named entity labels or part-of-speech tags.<br>
# **`sgd=optimizer`**: This specifies the optimizer to use for updating the model weights. In this case, the optimizer is called optimizer and is an instance of an SGD optimizer.<br>
# **`drop=0.35`**: This argument sets the dropout rate to 0.35. Dropout is a technique used to prevent overfitting in deep learning models, where a proportion of neurons are randomly dropped out during training to prevent the model from relying too heavily on any one neuron or set of neurons.<br>
# **`losses=losses1`**: This is a dictionary object that keeps track of the loss incurred during training. The losses1 object contains the current loss value and will be updated with the new loss value after this update.<br>
# Overall, this command is updating the nlp1 model instance with a new example using the SGD optimizer, with a dropout rate of 0.35, and keeping track of the loss values in the losses1 object.

# %% [markdown]
# #Tesing the Models along with default NLP Model - Performance Evaluation

# %%
#Test the NLP Models
#Default NLP Model
nlp3= spacy.load('en_core_web_sm') 
#Adding labels to default NLP Model
ner3= nlp3.get_pipe("ner") 
for label in labels:
    ner3.add_label(label)
#Testing on test_data
texts, annotations = zip(*test_data)
example1=[]
example2=[]
example3=[]
for i in range(0,len(texts)):
    doc1 = nlp1.make_doc(texts[i]) #Blank
    doc2 = nlp2.make_doc(texts[i]) #Existing
    doc3 = nlp3.make_doc(texts[i]) #Default
    example1.append(Example.from_dict(doc1, annotations[i]))
    example2.append(Example.from_dict(doc2, annotations[i]))
    example3.append(Example.from_dict(doc3, annotations[i]))
scores1=nlp1.evaluate(example1) #Blank
scores2=nlp2.evaluate(example2) #Existing
scores3=nlp3.evaluate(example3) #Default
# Out:
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Under the PMJAY scheme, people can get Empanelled ..." with entities "[(10, 15, 'ORG'), (39, 58, 'ORG'), (70, 79, 'PROCE...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Details are available at https://www.PMJAY.gov.in/..." with entities "[(37, 42, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMAMIT portal provides detailed information on..." with entities "[(4, 8, 'PERSON'), (55, 77, 'CSC'), (82, 87, 'ORG'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Under PMJAY, citizens can avail of financial assis..." with entities "[(6, 11, 'ORG'), (75, 94, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients under PMJAY are eligible to receive benef..." with entities "[(0, 7, 'PERSON'), (15, 20, 'ORG'), (63, 82, 'ORG'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY scheme provides health Insurance Company..." with entities "[(4, 9, 'ORG'), (33, 50, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMAM is also responsible for providing financial a..." with entities "[(0, 4, 'PERSON'), (122, 139, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Government has laid down clear eligibility cri..." with entities "[(64, 81, 'PERSON'), (88, 93, 'ORG'), (107, 124, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY Beneficiary shall be either be prescribe..." with entities "[(4, 21, 'PERSON'), (89, 100, 'PROCESS'), (104, 12...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY Beneficiary prescribed medical drugs and not..." with entities "[(0, 17, 'PERSON'), (61, 80, 'ORG'), (106, 118, 'P...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY identifies the PMJAY Beneficiary through the..." with entities "[(0, 5, 'ORG'), (21, 38, 'PERSON'), (51, 55, 'PERS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Service Parameters Response from PMJAY Beneficiary..." with entities "[(33, 50, 'PERSON'), (104, 123, 'ORG'), (137, 146,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY scheme has become an integral part of th..." with entities "[(4, 9, 'ORG'), (52, 69, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY facilitates Empanelled Hospitalization for t..." with entities "[(0, 5, 'ORG'), (18, 37, 'ORG'), (81, 99, 'PERSON'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The scheme also covers the cost of Empanelled Hosp..." with entities "[(35, 54, 'ORG'), (81, 100, 'PERSON'), (109, 128, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Feedback from people using the EHCPortal for P..." with entities "[(4, 12, 'DOCUMENT'), (35, 39, 'ORG'), (49, 54, 'O...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY scheme provides people with access to fr..." with entities "[(4, 9, 'ORG'), (53, 72, 'ORG'), (84, 93, 'PROCESS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The EHCPs created under PMJAY offer access to qual..." with entities "[(4, 8, 'ORG'), (24, 29, 'ORG'), (54, 65, 'PROCESS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Objective The success of PMJAY will be driven by t..." with entities "[(25, 30, 'ORG'), (78, 95, 'PERSON'), (102, 121, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides access to Empanelled Hospitalizatio..." with entities "[(0, 5, 'ORG'), (25, 44, 'ORG'), (81, 99, 'PERSON'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Patient can avail cashless Treatment and Empan..." with entities "[(4, 11, 'PERSON'), (31, 40, 'PROCESS'), (45, 64, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Only in case of not being Empanelled Hospitalized ..." with entities "[(26, 45, 'ORG'), (54, 71, 'PERSON')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides an online platform for the register..." with entities "[(0, 5, 'ORG'), (53, 70, 'PERSON'), (117, 121, 'OR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients can find out if they are eligible for the..." with entities "[(0, 7, 'PERSON'), (51, 56, 'ORG'), (80, 101, 'POR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY helps citizens to get access to quality heal..." with entities "[(0, 5, 'ORG'), (93, 112, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The PMJAY scheme covers the cost of Empanelled Hos..." with entities "[(4, 9, 'ORG'), (36, 55, 'ORG'), (85, 99, 'PERSON'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The General Doctor associated with the PMJAY progr..." with entities "[(4, 18, 'PERSON'), (39, 44, 'ORG'), (89, 106, 'OR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "In order to register for the PMJAY scheme, users m..." with entities "[(29, 34, 'ORG'), (71, 93, 'CSC'), (106, 110, 'PER...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The EHCPortal has been instrumental in helping peo..." with entities "[(4, 8, 'ORG'), (93, 98, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "For PMJAY Beneficiary requiring Empanelled Hospita..." with entities "[(4, 21, 'PERSON'), (32, 51, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Patients can easily avail the benefits of PMJAY by..." with entities "[(0, 7, 'PERSON'), (42, 47, 'ORG'), (75, 86, 'CSC'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "o Reiterate that the Empanelled Hospitalization se..." with entities "[(21, 40, 'ORG'), (62, 67, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Many people have found the EHCPortal to be a great..." with entities "[(27, 31, 'ORG'), (78, 83, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY ensures that every Patient is given access t..." with entities "[(0, 5, 'ORG'), (25, 32, 'PERSON'), (76, 94, 'PERS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PMJAY provides access to Diagnostics services thro..." with entities "[(0, 5, 'ORG'), (25, 36, 'PROCESS'), (90, 94, 'ORG...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(

# %% [markdown]
# This code evaluates the performance of two trained NER models, nlp1 and nlp2, using a list of test data called test_data. The zip function is used to extract the text and the annotations from each example in the test data, which are then used to create Example objects for each NER model.
#
# A loop is then used to iterate over each text in the test data. For each text, two Doc objects are created, one for each NER model, using the make_doc function. Then, two Example objects are created from each Doc and its corresponding annotations using the Example.from_dict method. These Example objects are stored in separate lists called example1 and example2.
#
# After all examples in the test data have been processed, the evaluate method is called on each NER model using its corresponding list of Example objects. This method calculates various metrics such as precision, recall, and F1-score for each named entity label, and returns a dictionary of these scores, as well as an overall score.
#
# The scores for each model are stored in the scores1 and scores2 variables, respectively, which can be used to compare the performance of the two models on the test data.

# %%
#Dropping the Columns with no values
score_df1= (pd.DataFrame.from_dict(scores1)).dropna(axis=1) #Blank
score_df2= (pd.DataFrame.from_dict(scores2)).dropna(axis=1) #Existing
score_df3= (pd.DataFrame.from_dict(scores3)).dropna(axis=1) #Default
#Renaming the required columns
score_df1.rename(columns = {'ents_p':'ents_p1', 'ents_r':'ents_r1', 'ents_f':'ents_f1', 'speed':'speed1'}, inplace = True)
score_df2.rename(columns = {'ents_p':'ents_p2', 'ents_r':'ents_r2', 'ents_f':'ents_f2', 'speed':'speed2'}, inplace = True)
score_df3.rename(columns = {'ents_p':'ents_p3', 'ents_r':'ents_r3', 'ents_f':'ents_f3', 'speed':'speed3'}, inplace = True)
#Dropping the irrelevant Columns
score_df1.drop(['token_acc','token_p','token_r','token_f','ents_per_type'], axis=1,inplace=True)
score_df2.drop(['token_acc','token_p','token_r','token_f','ents_per_type'], axis=1,inplace=True)
score_df3.drop(['token_acc','token_p','token_r','token_f','ents_per_type'], axis=1,inplace=True)

# %%
#NEW
res_score=pd.concat([score_df1,score_df2,score_df3],axis=1,join='inner')
res_score
# Out:
#              ents_p1   ents_r1   ents_f1        speed1   ents_p2  ents_r2  \
# CSC         0.989529  0.992126  0.990826  15324.516909  0.996078      1.0
# DOCUMENT    0.989529  0.992126  0.990826  15324.516909  0.996078      1.0
# MOBILE_APP  0.989529  0.992126  0.990826  15324.516909  0.996078      1.0
# ORG         0.989529  0.992126  0.990826  15324.516909  0.996078      1.0
# PERMISSION  0.989529  0.992126  0.990826  15324.516909  0.996078      1.0
# PERSON      0.989529  0.992126  0.990826  15324.516909  0.996078      1.0
# PORTAL      0.989529  0.992126  0.990826  15324.516909  0.996078      1.0
# PROCESS     0.989529  0.992126  0.990826  15324.516909  0.996078      1.0
#
#              ents_f2       speed2   ents_p3  ents_r3   ents_f3       speed3
# CSC         0.998035  4242.044031  0.341373  0.24147  0.282859  4338.991815
# DOCUMENT    0.998035  4242.044031  0.341373  0.24147  0.282859  4338.991815
# MOBILE_APP  0.998035  4242.044031  0.341373  0.24147  0.282859  4338.991815
# ORG         0.998035  4242.044031  0.341373  0.24147  0.282859  4338.991815
# PERMISSION  0.998035  4242.044031  0.341373  0.24147  0.282859  4338.991815
# PERSON      0.998035  4242.044031  0.341373  0.24147  0.282859  4338.991815
# PORTAL      0.998035  4242.044031  0.341373  0.24147  0.282859  4338.991815
# PROCESS     0.998035  4242.044031  0.341373  0.24147  0.282859  4338.991815

# %%
#Getting Average of all the scores
avg_val=[]
for v in res_score:
    sum=0
    for i in res_score[v].values:
        sum= sum+i
    sum= sum/len(res_score)
    avg_val.append(sum)

#For NLP Model 1 - [Trained on Blank Model]
avg_precision_1=str(round(avg_val[0],4))+" ("+str(round(avg_val[0]*100,2))+" %)"
avg_recall_1=str(round(avg_val[1],4))+" ("+str(round(avg_val[1]*100,2))+" %)"
avg_f1_score_1=str(round(avg_val[2],4))+" ("+str(round(avg_val[2]*100,2))+" %)"
avg_speed_1=round(avg_val[3],2)

#For NLP Model 2 - [Trained on Pre-existing Model]
avg_precision_2=str(round(avg_val[4],4))+" ("+str(round(avg_val[4]*100,2))+" %)"
avg_recall_2=str(round(avg_val[5],4))+" ("+str(round(avg_val[5]*100,2))+" %)"
avg_f1_score_2=str(round(avg_val[6],4))+" ("+str(round(avg_val[6]*100,2))+" %)"
avg_speed_2=round(avg_val[7],2)

#For Default NLP Model 
avg_precision_3=str(round(avg_val[8],4))+" ("+str(round(avg_val[8]*100,2))+" %)"
avg_recall_3=str(round(avg_val[9],4))+" ("+str(round(avg_val[9]*100,2))+" %)"
avg_f1_score_3=str(round(avg_val[10],4))+" ("+str(round(avg_val[10]*100,2))+" %)"
avg_speed_3=round(avg_val[11],2)

#Creating a DataFrame for all the three Scores
data = {'Metric': ['Precision', 'Recall', 'F1 Score', 'Speed (examples processed/sec)'],
        'Default NLP Model': [avg_precision_3, avg_recall_3, avg_f1_score_3, avg_speed_3],
        'NLP Model 1 -[Blank Base]': [avg_precision_1, avg_recall_1, avg_f1_score_1, avg_speed_1],
        'NLP Model 2 -[Pre-trained Base]': [avg_precision_2, avg_recall_2, avg_f1_score_2, avg_speed_2]}
performance_df = pd.DataFrame(data)
from tabulate import tabulate
print("Performance Evaluation\n",tabulate(performance_df, headers='keys', tablefmt='psql'))
# Out:
# Performance Evaluation
#  +----+--------------------------------+---------------------+-----------------------------+-----------------------------------+
# |    | Metric                         | Default NLP Model   | NLP Model 1 -[Blank Base]   | NLP Model 2 -[Pre-trained Base]   |
# |----+--------------------------------+---------------------+-----------------------------+-----------------------------------|
# |  0 | Precision                      | 0.3414 (34.14 %)    | 0.9895 (98.95 %)            | 0.9961 (99.61 %)                  |
# |  1 | Recall                         | 0.2415 (24.15 %)    | 0.9921 (99.21 %)            | 1.0 (100.0 %)                     |
# |  2 | F1 Score                       | 0.2829 (28.29 %)    | 0.9908 (99.08 %)            | 0.998 (99.8 %)                    |
# |  3 | Speed (examples processed/sec) | 4338.99             | 15324.52                    | 4242.04                           |
# +----+--------------------------------+---------------------+-----------------------------+-----------------------------------+

# %% [markdown]
# **Precision**: Precision is the ratio of correctly predicted positive results to the total number of predicted positive results. In the context of NLP, precision measures how many of the predicted entities or classifications were actually correct. For example, if the NLP model correctly identified 85 out of 100 entities, then the precision would be 85%.
#
# **Recall**: Recall is the ratio of correctly predicted positive results to the total number of actual positive results. In the context of NLP, recall measures how many of the actual entities or classifications were identified correctly by the model. For example, if the NLP model correctly identified 92 out of 100 entities, then the recall would be 92%.
#
# **F1 score**: F1 score is a weighted average of precision and recall, calculated as 2*(precision * recall)/(precision+recall). It ranges from 0 to 1, where a score of 1 represents perfect precision and recall, and a score of 0 represents the worst possible performance.
#
# **Speed**: Speed measures the time taken by the NLP model to process a given text. It is usually reported in terms of seconds per document or tokens per second.

# %% [markdown]
# NLP Model 1 is likely able to achieve these high scores because it has been trained on a large amount of data and is able to recognize patterns and relationships more effectively.
#
# NLP Model 2 has been pre-trained on a large corpus of text, which has allowed it to learn language patterns and relationships that it can apply to new data with high accuracy.
#
# In addition to performance metrics, the comparison also includes a measure of speed, which is the number of examples processed per second. NLP Model 1 has the highest speed followed by the default NLP model and NLP Model 2.
#
# Overall, this comparison shows that using a more advanced NLP model can greatly improve the accuracy of natural language processing, but may come at a cost of reduced speed. The choice of model will depend on the specific needs of the application, balancing the need for accuracy with the need for speed.

# %% [markdown]
# ##Conclusion
# The Precision, Recall and F1 Score of NLP Model 2 which is trained on existing "en_core_web_sm" is higher the that of NLP Model 1 which is trained from blank spacy "en" model.<br>
# Hence, we shall use NLP Model 2.
# #End Of File

# %%
import spacy
from spacy import displacy
from IPython.core.display import display, HTML

nlp= spacy.load('/content/drive/MyDrive/Final (Completed)/nlp_model_2')
t="The Patient checks eligibility throung PMJAY Kiosk or EHCP Registration Desk at any Empanelled Hospital. \
The BIS verifies the eligibility of the Patient and decides if he or she is a PMJAY Beneficiary. \
The Doctor decides if the Patient needs Hospitalization, Medication or further Diagnostics."
doc=nlp(t)
html = displacy.render(doc, style="ent")
display(HTML(html))
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Patient
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  checks eligibility throung
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PMJAY Kiosk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CSC</span>
# </mark>
#  or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EHCP Registration Desk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CSC</span>
# </mark>
#  at any
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Empanelled Hospital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BIS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PORTAL</span>
# </mark>
#  verifies the eligibility of the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Patient
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and decides if he or she is a
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PMJAY Beneficiary
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . The
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Doctor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  decides if the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Patient
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  needs Hospitalization, Medication or further
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Diagnostics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROCESS</span>
# </mark>
# .</div>
